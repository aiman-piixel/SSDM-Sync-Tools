# %%
import os
import glob2
import pandas as pd

# Input and output folder paths
folder_path = r"C:\Users\Aiman\Desktop\ssdm jb 1jul-31aug\raw"
output_folder = r"C:\Users\Aiman\Desktop\ssdm jb 1jul-31aug\appended"

# Get a list of subfolders in the input folder
subfolders = glob2.glob(os.path.join(folder_path, "*"))

# Iterate through each subfolder
for subfolder in subfolders:
    subfolder_name = os.path.basename(subfolder)
    output_file = os.path.join(output_folder, subfolder_name + ".csv")  # Change extension to CSV

    # Get a list of Excel files in the current subfolder
    filenames = glob2.glob(os.path.join(subfolder, "*.xlsx"))

    outputcsv = pd.DataFrame()

    # Iterate through each Excel file
    for file in filenames:
        df = pd.read_excel(file)
        df['Synced'] = 0  # Add a 'Synced' column filled with zeros
        outputcsv = pd.concat([outputcsv, df], ignore_index=True)  # Use pd.concat() for concatenation

    # Drop specific columns from the DataFrame
    columns_to_drop = [1, 4, 5, 6]
    outputcsv.drop(outputcsv.columns[columns_to_drop], axis=1, inplace=True)

    # Save the combined DataFrame to a CSV file
    outputcsv.to_csv(output_file, index=False)

    print("Final CSV file generated and saved to:", subfolder_name)
# Out:
# C:\Users\Aiman\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\Aiman\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\Aiman\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\Aiman\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...
