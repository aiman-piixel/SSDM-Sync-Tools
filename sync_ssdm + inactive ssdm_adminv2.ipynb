# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
import os
import time
import glob2
import pandas as pd
from IPython.display import clear_output
import sys

#adjust path accordingly to OS
#loginCSV = r"C:\Users\Aiman\Desktop\ssdm login jb 1mac-30jun.csv"
#excel_folder = r"C:\Users\Aiman\Desktop\appended ssdm 1mac-30jun"
loginCSV = "/Users/piixel/Downloads/ssdm damai jaya 16jul-16aug.csv"
excel_folder = "/Users/piixel/Downloads/DAMAI JAYA"

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--disable-extensions")

#ssdm category
category = {
    "ssdm1": ["MEMBANTU GURU JIKA ADA MAJLIS",
              "MENOLONG DAN MENGAWAL KELAS SEMASA GURU TIADA",
              "MEMBANTU GURU MENGAMBIL KEHADIRAN PELAJAR",
              "MEMBANTU GURU JIKA MEMERLUKAN BANTUAN",
              "MEMBANTU MENGANGKAT BUKU/BARANG GURU"
    ],
    "ssdm2": ["DATANG AWAL KE SEKOLAH", "BERDISIPLIN", "BERCAKAP DENGAN SOPAN",
              "BERPAKAIAN KEMAS", "MENYAPA/MEMBERI SALAM KEPADA GURU"
    ],
    "ssdm3": ["MENYUSUN KEMAS MEJA", "MEMBUANG DEBU/HABUK DI CERMIN/MEJA/DINDING",
              "MEMBERSIHKAN PAPAN HITAM", "MENGEMOP BILIK", "MENYAPU BILIK-BILIK KHAS"
    ],
    "ssdm4": ["MENYUSUN MEJA/PERABOT", "MENGHIAS BILIK",
              "MEMBERSIHKAN MEJA/PERABOT YANG BERDEBU", "MOP LANTAI",
              "MENYAPU SAMPAH-SARAP DI SEKELILING KELAS"
    ],
    "ssdm5": ["MUDAH BERINTERAKSI ATAU BERGAUL",
              "MENGHORMATI PENDAPAT ORANG LAIN",
              "BIJAK BERKOMUNIKASI UNTUK MENDAPATKAN MAKLUMAT",
              "MENJADI FASILATATOR"
    ],
    "ssdm6": ["MELAPOR KES MASALAH SOSIAL YANG SERIUS",
              "MELAPOR KES MEMBAWA/MENGGUNAKAN BARANG TERLARANG",
              "MELAPOR KES TIDAK BERDISIPLIN",
              "MELAPOR KES LEWAT KE SEKOLAH",
              "MELAPOR KES PONTENG SEKOLAH/KELAS"
    ],
    "ssdm7": ["MENYUSUN DAN MENCANTIK KAN KAWASAN TAMAN/LANDSKAP",
              "MEMOTONG RUMPUT YANG PANJANG",
              "MEMBANTU MENYIRAM POKO BUNGA",
              "MENGUTIP SAMPAH-SARAP YANG ADA",
              "MEMBANTU MENYAPU DAUN-DAUN KERING",
              "MEMBANTU MENYIRAM POKOK BUNGA"
    ],
    "ssdm8": ["MELAKUKAN DENGAN PENUH SEMANGAT",
              "SUKA MENOLONG ORANG LAIN",
              "MEMBANTU MENGEMAS SEMULA BARANG YANG DIGUNAKAN",
              "BEKERJASAMA MENGECAT DINDING",
              "MENUNJUKKAN KREATIVITI"
    ]
}

#to match item to ssdm category
def category_ssdm(amalanBaik):
    for ssdm, item in category.items():
        if amalanBaik in item:
            return ssdm
    return None

#return amalan baik value in dropdown
def dropdown_ssdm(category):
    select_amalanBaik = driver.find_element(By.XPATH, "//select[@name='AB']")
    select = Select(select_amalanBaik)
    if category == "ssdm1":
        select.select_by_value('1')
    elif category == "ssdm2":
        select.select_by_value('8')
    elif category == "ssdm3":
        select.select_by_value('4')
    elif category == "ssdm4":
        select.select_by_value('5')
    elif category == "ssdm5":
        select.select_by_value('7')
    elif category == "ssdm6":
        select.select_by_value('2')
    elif category == "ssdm7":
        select.select_by_value('3')
    elif category == "ssdm8":
        select.select_by_value('6')
    else:
        time.sleep(0.5)
        print("Item not valid")
        return "Invalid"

#return day value in dropdown
def return_day(DaySeries):
    select_date = driver.find_element(By.XPATH, "//select[@name='_b_hari_mula_tk']")
    select = Select(select_date)
    select.select_by_value(DaySeries)
        
#return month value in dropdown
def return_month(MonthSeries):
    select_month = driver.find_element(By.XPATH, "//select[@name='_b_bulan_mula_tk']")
    select = Select(select_month)
    if MonthSeries == "1":
        select.select_by_value('JAN')
    elif MonthSeries == "2":
        select.select_by_value('FEB')
    elif MonthSeries == "3":
        select.select_by_value('MAR')
    elif MonthSeries == "4":
        select.select_by_value('APR')
    elif MonthSeries == "5":
        select.select_by_value('MAY')
    elif MonthSeries == "6":
        select.select_by_value('JUN')
    elif MonthSeries == "7":
        select.select_by_value('JUL')
    elif MonthSeries == "8":
        select.select_by_value('AUG')
    elif MonthSeries == "9":
        select.select_by_value('SEP')
    elif MonthSeries == "10":
        select.select_by_value('OCT')
    elif MonthSeries == "11":
        select.select_by_value('NOV')
    else:
        select.select_by_value('DEC')

#return year value in dropdown
def return_year(YearSeries):
    select_year = driver.find_element(By.XPATH, "//select[@name='_b_tahun_mula_tk']")
    select = Select(select_year)
    select.select_by_value(YearSeries)

#return hour and AM/PM value in dropdown
def return_hour(HourSeries):
    select_hour = driver.find_element(By.XPATH, "//select[@name='jam']")
    select = Select(select_hour)
    if HourSeries == "13" or HourSeries == "1":
        select.select_by_value('01')
    elif HourSeries == "14" or HourSeries == "2":
        select.select_by_value('02')
    elif HourSeries == "15" or HourSeries == "3":
        select.select_by_value('03')
    elif HourSeries == "16" or HourSeries == "4":
        select.select_by_value('04')
    elif HourSeries == "17" or HourSeries == "5":
        select.select_by_value('05')
    elif HourSeries == "18" or HourSeries == "6":
        select.select_by_value('06')
    elif HourSeries == "19" or HourSeries == "7":
        select.select_by_value('07')
    elif HourSeries == "20" or HourSeries == "8":
        select.select_by_value('08')
    elif HourSeries == "21" or HourSeries == "9":
        select.select_by_value('09')
    elif HourSeries == "22" or HourSeries == "10":
        select.select_by_value('10')
    elif HourSeries == "23" or HourSeries == "11":
        select.select_by_value('11')
    else:
        select.select_by_value(HourSeries)
    
    select_AMPM = driver.find_element(By.XPATH, "//select[@name='am_pm']")
    select = Select(select_AMPM)
    if HourSeries == "12":
        select.select_by_value('PM')
    elif HourSeries == "13":
        select.select_by_value('PM')
    elif HourSeries == "14":
        select.select_by_value('PM')
    elif HourSeries == "15":
        select.select_by_value('PM')
    elif HourSeries == "16":
        select.select_by_value('PM')
    elif HourSeries == "17":
        select.select_by_value('PM')
    elif HourSeries == "18":
        select.select_by_value('PM')
    elif HourSeries == "19":
        select.select_by_value('PM')
    elif HourSeries == "20":
        select.select_by_value('PM')
    elif HourSeries == "21":
        select.select_by_value('PM')
    elif HourSeries == "22":
        select.select_by_value('PM')
    elif HourSeries == "23":
        select.select_by_value('PM')
    else:
        select.select_by_value('AM')
        
#return minute value in dropdown
def return_min(MinSeries):
    select_min = driver.find_element(By.XPATH, "//select[@name='minit']")
    select = Select(select_min)
    if MinSeries == "1":
        select.select_by_value('01')
    elif MinSeries == "2":
        select.select_by_value('02')
    elif MinSeries == "3":
        select.select_by_value('03')
    elif MinSeries == "4":
        select.select_by_value('04')
    elif MinSeries == "5":
        select.select_by_value('05')
    elif MinSeries == "6":
        select.select_by_value('06')
    elif MinSeries == "7":
        select.select_by_value('07')
    elif MinSeries == "8":
        select.select_by_value('08')
    elif MinSeries == "9":
        select.select_by_value('09')
    else:
        select.select_by_value(MinSeries)
    
def close_driver():
    try:
        driver.quit()
    except Exception as e:
        print("An error occurred while closing the WebDriver:", e)
    
#read content in ssdm login csv
df_login = pd.read_csv(loginCSV)
schoolName = df_login['NAME']
ssdmID = df_login['ID']
ssdmPass = df_login['PASS']
schoolEmail = df_login['EMAIL']
startPage = df_login['START']
endPage = df_login['END']
statusPrep = df_login['PREPPED'].to_numpy()
statusDone = df_login['DONE'].to_numpy()

#list out all excel files in excel folder
fileNames = glob2.glob(os.path.join(excel_folder + "/*.xlsx"))
fileNames.sort()

for i in range(len(schoolName)):

    try:
        ############################set ssdm submission inactive in adminv2################################

        #check prep status
        if statusPrep[i]==1:
            print(schoolName[i] +" has already been prepped")
            pass

        else:
            driver = webdriver.Chrome(options=chrome_options)
            wait = WebDriverWait(driver, 10)
            driver.set_script_timeout(10)
            driver.get("https://adminv2.studentqr.com/login")

            login_box, pass_box = wait.until(EC.visibility_of_all_elements_located((By.CSS_SELECTOR , "input[name='email'], input[name='password']")))
            login_box.send_keys(schoolEmail[i])
            pass_box.send_keys('password')
            wait.until(EC.element_to_be_clickable((By.XPATH, "//button[@type='submit']"))).click()
            #let the page load after signing in
            time.sleep(2)

            #set page range for each school
            start_page = startPage[i]
            end_page = endPage[i]

            #loop through from start page to end page and set submission to inactive
            for page_number in range(start_page, end_page + 1):
                page_url = f"https://adminv2.studentqr.com/ssdm?page={page_number}"
                driver.get(page_url)
                time.sleep(1.5)
                #wait for page to load

                #check all checkboxes
                checkboxes = driver.find_elements(By.XPATH, "//input[@type='checkbox']")
                total_checkboxes = len(checkboxes)
                for check_number in range(total_checkboxes):
                    driver.execute_script("arguments[0].click();", checkboxes[check_number])

                #set item to inactive
                select_element = driver.find_element(By.XPATH, "//select[@name='statusCheckbox']")
                select = Select(select_element)
                select.select_by_value('2')

                #update status
                wait.until(EC.element_to_be_clickable((By.XPATH ,"//button[@id='updateStatusButton']"))).click()
                time.sleep(1)
                alert = wait.until(EC.alert_is_present())
                if alert:
                    alert.accept()
                driver.switch_to.default_content()
                time.sleep(4)

                #check if start and end page is the same, end loop if same
                if start_page==end_page:
                    break

            #update school prep status
            statusPrep[i]=1
            df_login['PREPPED'] = statusPrep
            df_login.to_csv(loginCSV, index=False)

            driver.close()
            time.sleep(2)

        ###############################submit ssdm data to ssdm portal####################################

        #check done status
        if statusDone[i]==1:
            print(schoolName[i] +" has already been synced")
            pass

        else:
            #read ssdm data from excel file
            df = pd.read_excel(fileNames[i])
            
            DateTime = df["Date & Time"].astype('string')
            
            # Extract year, month, day, hour, and minute components using vectorized operations
            df["Year"] = df["Date & Time"].dt.year
            df["Month"] = df["Date & Time"].dt.month
            df["Day"] = df["Date & Time"].dt.day
            df["Hour"] = df["Date & Time"].dt.hour
            df["Minute"] = df["Date & Time"].dt.minute

            student_name = df['Student']
            item = df['Item']
            teacher = df['Awarded by']
            synced = df['Synced'].to_numpy()

            driver = webdriver.Chrome(options=chrome_options)
            wait = WebDriverWait(driver, 10)
            driver.set_script_timeout(10)

            driver.get("https://ssdm.moe.gov.my/")

            login_box, pass_box = wait.until(EC.visibility_of_all_elements_located((By.CSS_SELECTOR , "input[name='id'], input[name='password']")))
            login_box.send_keys(ssdmID[i])
            pass_box.send_keys(ssdmPass[i])
            wait.until(EC.element_to_be_clickable((By.XPATH, "//input[@class='button']"))).click()

            totalStudent = len(student_name)
            print("Total submission: "+ str(totalStudent))

            for x in range(len(student_name)):
                #check if submission is already synced
                if synced[x]==1:
                    totalStudent-=1
                    print("This submission has already been synced")
                    print("Remaining submissions :"+ str(totalStudent))
                    continue
                name_search = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR , "input[name='nama']")))        
                name_search.send_keys(student_name[x])
                wait.until(EC.element_to_be_clickable((By.XPATH, "//input[@name='cari']"))).click()
                fail_message = driver.find_elements(By.XPATH, "//span[text()='Maaf tiada padanan dengan data yang di cari dalam pangkalan data murid (APDM)']")
                #check if student is available in database, skip if not present
                if len(fail_message) >0:
                    print(student_name[x]+" is not available in the database ")
                    totalStudent-=1
                    print("Remaining submissions :"+ str(totalStudent))
                    #update sync status
                    synced[x]=1
                    df['Synced'] = synced
                    df.to_excel(fileNames[i], index=False)
                    continue
                wait.until(EC.element_to_be_clickable((By.XPATH, "//a[contains(text(),'Papar Kes')]"))).click()
                wait.until(EC.element_to_be_clickable((By.XPATH, "//input[@value='Tambah Amalan Baik']"))).click()

                #fills out keterangan
                keterangan = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR , "textarea[name='keteranganamalanbaik']")))
                keterangan.send_keys(item[x])
                #select tempat
                select_tempat = driver.find_element(By.XPATH, "//select[@name='TEMPAT']")
                select = Select(select_tempat)
                select.select_by_value('01')
                #select amalan baik
                cat_ssdm = category_ssdm(item[x])

                #check if item is valid or not
                AB = dropdown_ssdm(cat_ssdm)
                if AB == "Invalid":
                    totalStudent-=1
                    print("Remaining submissions :"+ str(totalStudent))
                    driver.get("https://ssdm.moe.gov.my/kemaskini_murid.cfm")
                    continue

                #select date
                day = df["Day"][x]
                return_day(str(day))
                month = df["Month"][x]
                return_month(str(month))
                #select time
                hour = df["Hour"][x]
                return_hour(str(hour))
                minute = df["Minute"][x]
                return_min(str(minute))
                #select teacher
                select_cikgu = driver.find_element(By.XPATH, "//select[@name='papar_guru']")
                select = Select(select_cikgu)
                select.select_by_visible_text(teacher[x])
                #click checkbox
                driver.find_element(By.XPATH, "//input[@type='checkbox']").click()
                #submit ssdm
                driver.find_element(By.XPATH, "//input[@name='simpan_amalanbaik']").click()

                #update sync status
                synced[x]=1
                df['Synced'] = synced
                df.drop(['Year', 'Month', 'Day', 'Hour', 'Minute'], axis=1)
                df.to_excel(fileNames[i], index=False)

                #handle alert popup
                alert = wait.until(EC.alert_is_present())
                if alert:
                    alert.accept()
                driver.switch_to.default_content()

                totalStudent-=1
                print("Sync is successful!")
                print("Remaining submissions :"+ str(totalStudent))

                driver.find_element(By.XPATH, "//a[@href='kemaskini_murid.cfm']").click()

            clear_output()
            print("Syncing for " +schoolName[i]+ " is done")

            #update school sync status
            statusDone[i]=1
            df_login['DONE'] = statusDone
            df_login.to_csv(loginCSV, index=False)

            driver.close()

    except Exception as e:
        print("An error occured:", e)
        sys.exit("Error encountered. Stopping the script.")  # Stop the script
    finally:
        close_driver()

print("Sync process is done for all schools")
# Out:
# SMK DAMAI JAYA has already been prepped
# Total submission: 14953
# This submission has already been synced
# Remaining submissions :14952
# This submission has already been synced
# Remaining submissions :14951
# This submission has already been synced
# Remaining submissions :14950
# This submission has already been synced
# Remaining submissions :14949
# This submission has already been synced
# Remaining submissions :14948
# This submission has already been synced
# Remaining submissions :14947
# This submission has already been synced
# Remaining submissions :14946
# This submission has already been synced
# Remaining submissions :14945
# This submission has already been synced
# Remaining submissions :14944
# This submission has already been synced
# Remaining submissions :14943
# This submission has already been synced
# Remaining submissions :14942
# This submission has already been synced
# Remaining submissions :14941
# This submission has already been synced
# Remaining submissions :14940
# This submission has already been synced
# Remaining submissions :14939
# This submission has already been synced
# Remaining submissions :14938
# This submission has already been synced
# Remaining submissions :14937
# This submission has already been synced
# Remaining submissions :14936
# This submission has already been synced
# Remaining submissions :14935
# This submission has already been synced
# Remaining submissions :14934
# This submission has already been synced
# Remaining submissions :14933
# This submission has already been synced
# Remaining submissions :14932
# This submission has already been synced
# Remaining submissions :14931
# This submission has already been synced
# Remaining submissions :14930
# This submission has already been synced
# Remaining submissions :14929
# This submission has already been synced
# Remaining submissions :14928
# This submission has already been synced
# Remaining submissions :14927
# This submission has already been synced
# Remaining submissions :14926
# This submission has already been synced
# Remaining submissions :14925
# This submission has already been synced
# Remaining submissions :14924
# This submission has already been synced
# Remaining submissions :14923
# This submission has already been synced
# Remaining submissions :14922
# This submission has already been synced
# Remaining submissions :14921
# This submission has already been synced
# Remaining submissions :14920
# This submission has already been synced
# Remaining submissions :14919
# This submission has already been synced
# Remaining submissions :14918
# This submission has already been synced
# Remaining submissions :14917
# This submission has already been synced
# Remaining submissions :14916
# This submission has already been synced
# Remaining submissions :14915
# This submission has already been synced
# Remaining submissions :14914
# This submission has already been synced
# Remaining submissions :14913
# This submission has already been synced
# Remaining submissions :14912
# This submission has already been synced
# Remaining submissions :14911
# This submission has already been synced
# Remaining submissions :14910
# This submission has already been synced
# Remaining submissions :14909
# This submission has already been synced
# Remaining submissions :14908
# This submission has already been synced
# Remaining submissions :14907
# This submission has already been synced
# Remaining submissions :14906
# This submission has already been synced
# Remaining submissions :14905
# This submission has already been synced
# Remaining submissions :14904
# This submission has already been synced
# Remaining submissions :14903
# This submission has already been synced
# Remaining submissions :14902
# This submission has already been synced
# Remaining submissions :14901
# This submission has already been synced
# Remaining submissions :14900
# This submission has already been synced
# Remaining submissions :14899
# This submission has already been synced
# Remaining submissions :14898
# This submission has already been synced
# Remaining submissions :14897
# This submission has already been synced
# Remaining submissions :14896
# This submission has already been synced
# Remaining submissions :14895
# This submission has already been synced
# Remaining submissions :14894
# This submission has already been synced
# Remaining submissions :14893
# This submission has already been synced
# Remaining submissions :14892
# This submission has already been synced
# Remaining submissions :14891
# This submission has already been synced
# Remaining submissions :14890
# This submission has already been synced
# Remaining submissions :14889
# This submission has already been synced
# Remaining submissions :14888
# This submission has already been synced
# Remaining submissions :14887
# This submission has already been synced
# Remaining submissions :14886
# This submission has already been synced
# Remaining submissions :14885
# This submission has already been synced
# Remaining submissions :14884
# This submission has already been synced
# Remaining submissions :14883
# This submission has already been synced
# Remaining submissions :14882
# This submission has already been synced
# Remaining submissions :14881
# This submission has already been synced
# Remaining submissions :14880
# This submission has already been synced
# Remaining submissions :14879
# This submission has already been synced
# Remaining submissions :14878
# This submission has already been synced
# Remaining submissions :14877
# This submission has already been synced
# Remaining submissions :14876
# This submission has already been synced
# Remaining submissions :14875
# This submission has already been synced
# Remaining submissions :14874
# This submission has already been synced
# Remaining submissions :14873
# This submission has already been synced
# Remaining submissions :14872
# This submission has already been synced
# Remaining submissions :14871
# This submission has already been synced
# Remaining submissions :14870
# This submission has already been synced
# Remaining submissions :14869
# This submission has already been synced
# Remaining submissions :14868
# This submission has already been synced
# Remaining submissions :14867
# This submission has already been synced
# Remaining submissions :14866
# This submission has already been synced
# Remaining submissions :14865
# This submission has already been synced
# Remaining submissions :14864
# This submission has already been synced
# Remaining submissions :14863
# This submission has already been synced
# Remaining submissions :14862
# This submission has already been synced
# Remaining submissions :14861
# This submission has already been synced
# Remaining submissions :14860
# This submission has already been synced
# Remaining submissions :14859
# This submission has already been synced
# Remaining submissions :14858
# This submission has already been synced
# Remaining submissions :14857
# This submission has already been synced
# Remaining submissions :14856
# This submission has already been synced
# Remaining submissions :14855
# This submission has already been synced
# Remaining submissions :14854
# This submission has already been synced
# Remaining submissions :14853
# This submission has already been synced
# Remaining submissions :14852
# This submission has already been synced
# Remaining submissions :14851
# This submission has already been synced
# Remaining submissions :14850
# This submission has already been synced
# Remaining submissions :14849
# This submission has already been synced
# Remaining submissions :14848
# This submission has already been synced
# Remaining submissions :14847
# This submission has already been synced
# Remaining submissions :14846
# This submission has already been synced
# Remaining submissions :14845
# This submission has already been synced
# Remaining submissions :14844
# This submission has already been synced
# Remaining submissions :14843
# This submission has already been synced
# Remaining submissions :14842
# This submission has already been synced
# Remaining submissions :14841
# This submission has already been synced
# Remaining submissions :14840
# This submission has already been synced
# Remaining submissions :14839
# This submission has already been synced
# Remaining submissions :14838
# This submission has already been synced
# Remaining submissions :14837
# This submission has already been synced
# Remaining submissions :14836
# This submission has already been synced
# Remaining submissions :14835
# This submission has already been synced
# Remaining submissions :14834
# This submission has already been synced
# Remaining submissions :14833
# This submission has already been synced
# Remaining submissions :14832
# This submission has already been synced
# Remaining submissions :14831
# This submission has already been synced
# Remaining submissions :14830
# This submission has already been synced
# Remaining submissions :14829
# This submission has already been synced
# Remaining submissions :14828
# This submission has already been synced
# Remaining submissions :14827
# This submission has already been synced
# Remaining submissions :14826
# This submission has already been synced
# Remaining submissions :14825
# This submission has already been synced
# Remaining submissions :14824
# This submission has already been synced
# Remaining submissions :14823
# This submission has already been synced
# Remaining submissions :14822
# This submission has already been synced
# Remaining submissions :14821
# This submission has already been synced
# Remaining submissions :14820
# This submission has already been synced
# Remaining submissions :14819
# This submission has already been synced
# Remaining submissions :14818
# This submission has already been synced
# Remaining submissions :14817
# This submission has already been synced
# Remaining submissions :14816
# This submission has already been synced
# Remaining submissions :14815
# This submission has already been synced
# Remaining submissions :14814
# This submission has already been synced
# Remaining submissions :14813
# This submission has already been synced
# Remaining submissions :14812
# This submission has already been synced
# Remaining submissions :14811
# This submission has already been synced
# Remaining submissions :14810
# This submission has already been synced
# Remaining submissions :14809
# This submission has already been synced
# Remaining submissions :14808
# This submission has already been synced
# Remaining submissions :14807
# This submission has already been synced
# Remaining submissions :14806
# This submission has already been synced
# Remaining submissions :14805
# This submission has already been synced
# Remaining submissions :14804
# This submission has already been synced
# Remaining submissions :14803
# This submission has already been synced
# Remaining submissions :14802
# This submission has already been synced
# Remaining submissions :14801
# This submission has already been synced
# Remaining submissions :14800
# This submission has already been synced
# Remaining submissions :14799
# This submission has already been synced
# Remaining submissions :14798
# This submission has already been synced
# Remaining submissions :14797
# This submission has already been synced
# Remaining submissions :14796
# This submission has already been synced
# Remaining submissions :14795
# This submission has already been synced
# Remaining submissions :14794
# This submission has already been synced
# Remaining submissions :14793
# This submission has already been synced
# Remaining submissions :14792
# This submission has already been synced
# Remaining submissions :14791
# This submission has already been synced
# Remaining submissions :14790
# This submission has already been synced
# Remaining submissions :14789
# This submission has already been synced
# Remaining submissions :14788
# This submission has already been synced
# Remaining submissions :14787
# This submission has already been synced
# Remaining submissions :14786
# This submission has already been synced
# Remaining submissions :14785
# This submission has already been synced
# Remaining submissions :14784
# This submission has already been synced
# Remaining submissions :14783
# This submission has already been synced
# Remaining submissions :14782
# This submission has already been synced
# Remaining submissions :14781
# This submission has already been synced
# Remaining submissions :14780
# This submission has already been synced
# Remaining submissions :14779
# This submission has already been synced
# Remaining submissions :14778
# This submission has already been synced
# Remaining submissions :14777
# This submission has already been synced
# Remaining submissions :14776
# This submission has already been synced
# Remaining submissions :14775
# This submission has already been synced
# Remaining submissions :14774
# This submission has already been synced
# Remaining submissions :14773
# This submission has already been synced
# Remaining submissions :14772
# This submission has already been synced
# Remaining submissions :14771
# This submission has already been synced
# Remaining submissions :14770
# This submission has already been synced
# Remaining submissions :14769
# This submission has already been synced
# Remaining submissions :14768
# This submission has already been synced
# Remaining submissions :14767
# This submission has already been synced
# Remaining submissions :14766
# This submission has already been synced
# Remaining submissions :14765
# This submission has already been synced
# Remaining submissions :14764
# This submission has already been synced
# Remaining submissions :14763
# This submission has already been synced
# Remaining submissions :14762
# This submission has already been synced
# Remaining submissions :14761
# This submission has already been synced
# Remaining submissions :14760
# This submission has already been synced
# Remaining submissions :14759
# This submission has already been synced
# Remaining submissions :14758
# This submission has already been synced
# Remaining submissions :14757
# This submission has already been synced
# Remaining submissions :14756
# This submission has already been synced
# Remaining submissions :14755
# This submission has already been synced
# Remaining submissions :14754
# This submission has already been synced
# Remaining submissions :14753
# This submission has already been synced
# Remaining submissions :14752
# This submission has already been synced
# Remaining submissions :14751
# This submission has already been synced
# Remaining submissions :14750
# This submission has already been synced
# Remaining submissions :14749
# This submission has already been synced
# Remaining submissions :14748
# This submission has already been synced
# Remaining submissions :14747
# This submission has already been synced
# Remaining submissions :14746
# This submission has already been synced
# Remaining submissions :14745
# This submission has already been synced
# Remaining submissions :14744
# This submission has already been synced
# Remaining submissions :14743
# This submission has already been synced
# Remaining submissions :14742
# This submission has already been synced
# Remaining submissions :14741
# This submission has already been synced
# Remaining submissions :14740
# This submission has already been synced
# Remaining submissions :14739
# This submission has already been synced
# Remaining submissions :14738
# This submission has already been synced
# Remaining submissions :14737
# This submission has already been synced
# Remaining submissions :14736
# This submission has already been synced
# Remaining submissions :14735
# This submission has already been synced
# Remaining submissions :14734
# This submission has already been synced
# Remaining submissions :14733
# This submission has already been synced
# Remaining submissions :14732
# This submission has already been synced
# Remaining submissions :14731
# This submission has already been synced
# Remaining submissions :14730
# This submission has already been synced
# Remaining submissions :14729
# This submission has already been synced
# Remaining submissions :14728
# This submission has already been synced
# Remaining submissions :14727
# This submission has already been synced
# Remaining submissions :14726
# This submission has already been synced
# Remaining submissions :14725
# This submission has already been synced
# Remaining submissions :14724
# This submission has already been synced
# Remaining submissions :14723
# This submission has already been synced
# Remaining submissions :14722
# This submission has already been synced
# Remaining submissions :14721
# This submission has already been synced
# Remaining submissions :14720
# This submission has already been synced
# Remaining submissions :14719
# This submission has already been synced
# Remaining submissions :14718
# This submission has already been synced
# Remaining submissions :14717
# This submission has already been synced
# Remaining submissions :14716
# This submission has already been synced
# Remaining submissions :14715
# This submission has already been synced
# Remaining submissions :14714
# This submission has already been synced
# Remaining submissions :14713
# This submission has already been synced
# Remaining submissions :14712
# This submission has already been synced
# Remaining submissions :14711
# This submission has already been synced
# Remaining submissions :14710
# This submission has already been synced
# Remaining submissions :14709
# This submission has already been synced
# Remaining submissions :14708
# This submission has already been synced
# Remaining submissions :14707
# This submission has already been synced
# Remaining submissions :14706
# This submission has already been synced
# Remaining submissions :14705
# This submission has already been synced
# Remaining submissions :14704
# This submission has already been synced
# Remaining submissions :14703
# This submission has already been synced
# Remaining submissions :14702
# This submission has already been synced
# Remaining submissions :14701
# This submission has already been synced
# Remaining submissions :14700
# This submission has already been synced
# Remaining submissions :14699
# This submission has already been synced
# Remaining submissions :14698
# This submission has already been synced
# Remaining submissions :14697
# This submission has already been synced
# Remaining submissions :14696
# This submission has already been synced
# Remaining submissions :14695
# This submission has already been synced
# Remaining submissions :14694
# This submission has already been synced
# Remaining submissions :14693
# This submission has already been synced
# Remaining submissions :14692
# This submission has already been synced
# Remaining submissions :14691
# This submission has already been synced
# Remaining submissions :14690
# This submission has already been synced
# Remaining submissions :14689
# This submission has already been synced
# Remaining submissions :14688
# This submission has already been synced
# Remaining submissions :14687
# This submission has already been synced
# Remaining submissions :14686
# This submission has already been synced
# Remaining submissions :14685
# This submission has already been synced
# Remaining submissions :14684
# This submission has already been synced
# Remaining submissions :14683
# This submission has already been synced
# Remaining submissions :14682
# This submission has already been synced
# Remaining submissions :14681
# This submission has already been synced
# Remaining submissions :14680
# This submission has already been synced
# Remaining submissions :14679
# This submission has already been synced
# Remaining submissions :14678
# This submission has already been synced
# Remaining submissions :14677
# This submission has already been synced
# Remaining submissions :14676
# This submission has already been synced
# Remaining submissions :14675
# This submission has already been synced
# Remaining submissions :14674
# This submission has already been synced
# Remaining submissions :14673
# This submission has already been synced
# Remaining submissions :14672
# This submission has already been synced
# Remaining submissions :14671
# This submission has already been synced
# Remaining submissions :14670
# This submission has already been synced
# Remaining submissions :14669
# This submission has already been synced
# Remaining submissions :14668
# This submission has already been synced
# Remaining submissions :14667
# This submission has already been synced
# Remaining submissions :14666
# This submission has already been synced
# Remaining submissions :14665
# This submission has already been synced
# Remaining submissions :14664
# This submission has already been synced
# Remaining submissions :14663
# This submission has already been synced
# Remaining submissions :14662
# This submission has already been synced
# Remaining submissions :14661
# This submission has already been synced
# Remaining submissions :14660
# This submission has already been synced
# Remaining submissions :14659
# This submission has already been synced
# Remaining submissions :14658
# This submission has already been synced
# Remaining submissions :14657
# This submission has already been synced
# Remaining submissions :14656
# This submission has already been synced
# Remaining submissions :14655
# This submission has already been synced
# Remaining submissions :14654
# This submission has already been synced
# Remaining submissions :14653
# This submission has already been synced
# Remaining submissions :14652
# This submission has already been synced
# Remaining submissions :14651
# This submission has already been synced
# Remaining submissions :14650
# This submission has already been synced
# Remaining submissions :14649
# This submission has already been synced
# Remaining submissions :14648
# This submission has already been synced
# Remaining submissions :14647
# This submission has already been synced
# Remaining submissions :14646
# This submission has already been synced
# Remaining submissions :14645
# This submission has already been synced
# Remaining submissions :14644
# This submission has already been synced
# Remaining submissions :14643
# This submission has already been synced
# Remaining submissions :14642
# This submission has already been synced
# Remaining submissions :14641
# This submission has already been synced
# Remaining submissions :14640
# This submission has already been synced
# Remaining submissions :14639
# This submission has already been synced
# Remaining submissions :14638
# This submission has already been synced
# Remaining submissions :14637
# This submission has already been synced
# Remaining submissions :14636
# This submission has already been synced
# Remaining submissions :14635
# This submission has already been synced
# Remaining submissions :14634
# This submission has already been synced
# Remaining submissions :14633
# This submission has already been synced
# Remaining submissions :14632
# This submission has already been synced
# Remaining submissions :14631
# This submission has already been synced
# Remaining submissions :14630
# This submission has already been synced
# Remaining submissions :14629
# This submission has already been synced
# Remaining submissions :14628
# This submission has already been synced
# Remaining submissions :14627
# This submission has already been synced
# Remaining submissions :14626
# This submission has already been synced
# Remaining submissions :14625
# This submission has already been synced
# Remaining submissions :14624
# This submission has already been synced
# Remaining submissions :14623
# This submission has already been synced
# Remaining submissions :14622
# This submission has already been synced
# Remaining submissions :14621
# This submission has already been synced
# Remaining submissions :14620
# This submission has already been synced
# Remaining submissions :14619
# This submission has already been synced
# Remaining submissions :14618
# This submission has already been synced
# Remaining submissions :14617
# This submission has already been synced
# Remaining submissions :14616
# This submission has already been synced
# Remaining submissions :14615
# This submission has already been synced
# Remaining submissions :14614
# This submission has already been synced
# Remaining submissions :14613
# This submission has already been synced
# Remaining submissions :14612
# This submission has already been synced
# Remaining submissions :14611
# This submission has already been synced
# Remaining submissions :14610
# This submission has already been synced
# Remaining submissions :14609
# This submission has already been synced
# Remaining submissions :14608
# This submission has already been synced
# Remaining submissions :14607
# This submission has already been synced
# Remaining submissions :14606
# This submission has already been synced
# Remaining submissions :14605
# This submission has already been synced
# Remaining submissions :14604
# This submission has already been synced
# Remaining submissions :14603
# This submission has already been synced
# Remaining submissions :14602
# This submission has already been synced
# Remaining submissions :14601
# This submission has already been synced
# Remaining submissions :14600
# This submission has already been synced
# Remaining submissions :14599
# This submission has already been synced
# Remaining submissions :14598
# This submission has already been synced
# Remaining submissions :14597
# This submission has already been synced
# Remaining submissions :14596
# This submission has already been synced
# Remaining submissions :14595
# This submission has already been synced
# Remaining submissions :14594
# This submission has already been synced
# Remaining submissions :14593
# This submission has already been synced
# Remaining submissions :14592
# This submission has already been synced
# Remaining submissions :14591
# This submission has already been synced
# Remaining submissions :14590
# This submission has already been synced
# Remaining submissions :14589
# This submission has already been synced
# Remaining submissions :14588
# This submission has already been synced
# Remaining submissions :14587
# This submission has already been synced
# Remaining submissions :14586
# This submission has already been synced
# Remaining submissions :14585
# This submission has already been synced
# Remaining submissions :14584
# This submission has already been synced
# Remaining submissions :14583
# This submission has already been synced
# Remaining submissions :14582
# This submission has already been synced
# Remaining submissions :14581
# This submission has already been synced
# Remaining submissions :14580
# This submission has already been synced
# Remaining submissions :14579
# This submission has already been synced
# Remaining submissions :14578
# This submission has already been synced
# Remaining submissions :14577
# This submission has already been synced
# Remaining submissions :14576
# This submission has already been synced
# Remaining submissions :14575
# This submission has already been synced
# Remaining submissions :14574
# This submission has already been synced
# Remaining submissions :14573
# This submission has already been synced
# Remaining submissions :14572
# This submission has already been synced
# Remaining submissions :14571
# This submission has already been synced
# Remaining submissions :14570
# This submission has already been synced
# Remaining submissions :14569
# This submission has already been synced
# Remaining submissions :14568
# This submission has already been synced
# Remaining submissions :14567
# This submission has already been synced
# Remaining submissions :14566
# This submission has already been synced
# Remaining submissions :14565
# This submission has already been synced
# Remaining submissions :14564
# This submission has already been synced
# Remaining submissions :14563
# This submission has already been synced
# Remaining submissions :14562
# This submission has already been synced
# Remaining submissions :14561
# This submission has already been synced
# Remaining submissions :14560
# This submission has already been synced
# Remaining submissions :14559
# This submission has already been synced
# Remaining submissions :14558
# This submission has already been synced
# Remaining submissions :14557
# This submission has already been synced
# Remaining submissions :14556
# This submission has already been synced
# Remaining submissions :14555
# This submission has already been synced
# Remaining submissions :14554
# This submission has already been synced
# Remaining submissions :14553
# This submission has already been synced
# Remaining submissions :14552
# This submission has already been synced
# Remaining submissions :14551
# This submission has already been synced
# Remaining submissions :14550
# This submission has already been synced
# Remaining submissions :14549
# This submission has already been synced
# Remaining submissions :14548
# This submission has already been synced
# Remaining submissions :14547
# This submission has already been synced
# Remaining submissions :14546
# This submission has already been synced
# Remaining submissions :14545
# This submission has already been synced
# Remaining submissions :14544
# This submission has already been synced
# Remaining submissions :14543
# This submission has already been synced
# Remaining submissions :14542
# This submission has already been synced
# Remaining submissions :14541
# This submission has already been synced
# Remaining submissions :14540
# This submission has already been synced
# Remaining submissions :14539
# This submission has already been synced
# Remaining submissions :14538
# This submission has already been synced
# Remaining submissions :14537
# This submission has already been synced
# Remaining submissions :14536
# This submission has already been synced
# Remaining submissions :14535
# This submission has already been synced
# Remaining submissions :14534
# This submission has already been synced
# Remaining submissions :14533
# This submission has already been synced
# Remaining submissions :14532
# This submission has already been synced
# Remaining submissions :14531
# This submission has already been synced
# Remaining submissions :14530
# This submission has already been synced
# Remaining submissions :14529
# This submission has already been synced
# Remaining submissions :14528
# Sync is successful!
# Remaining submissions :14527
# Sync is successful!
# Remaining submissions :14526
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f8762191a10>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/613685996fd68e76037d609353ec74b2
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f8753432b90>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/613685996fd68e76037d609353ec74b2
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f87707c6a90>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/613685996fd68e76037d609353ec74b2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_1/c3p6n34x7s73jyj1_5n9nt7r0000gn/T/ipykernel_66775/1977013386.py in <module>
#     357                 name_search = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR , "input[name='nama']")))
#     358                 name_search.send_keys(student_name[x])
# --> 359                 wait.until(EC.element_to_be_clickable((By.XPATH, "//input[@name='cari']"))).click()
#     360                 fail_message = driver.find_elements(By.XPATH, "//span[text()='Maaf tiada padanan dengan data yang di cari dalam pangkalan data murid (APDM)']")
#     361                 #check if student is available in database, skip if not present
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      92     def click(self) -> None:
#      93         """Clicks the element."""
# ---> 94         self._execute(Command.CLICK_ELEMENT)
#      95
#      96     def submit(self):
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     393             params = {}
#     394         params["id"] = self._id
# --> 395         return self._parent.execute(command, params)
#     396
#     397     def find_element(self, by=By.ID, value=None) -> WebElement:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     341                 params["sessionId"] = self.session_id
#     342
# --> 343         response = self.command_executor.execute(driver_command, params)
#     344         if response:
#     345             self.error_handler.check_response(response)
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     289         data = utils.dump_json(params)
#     290         url = f"{self._url}{path}"
# --> 291         return self._request(command_info[0], url, body=data)
#     292
#     293     def _request(self, method, url, body=None):
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     310
#     311         if self.keep_alive:
# --> 312             response = self._conn.request(method, url, body=body, headers=headers)
#     313             statuscode = response.status
#     314         else:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77         else:
#      78             return self.request_encode_body(
# ---> 79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#      81
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374             response = conn.urlopen(method, url, **kw)
#     375         else:
# --> 376             response = conn.urlopen(method, u.request_uri, **kw)
#     377
#     378         redirect_location = redirect and response.get_redirect_location()
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     708                 body=body,
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#     712
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/envs/py37/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# ~/anaconda3/envs/py37/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~/anaconda3/envs/py37/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~/anaconda3/envs/py37/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
